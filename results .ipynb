# %% [markdown]
# # ECE-143-Wildfire-Project
#
# The Group Repository containing everyone's code.
#
# **Team Members:**
#
# David Belman, Aiden Rosen, Mahesh
# Ananthakrishnan Rameshkumar, Boran Jia, & Jacob Brown
#
#
# ## Objective:
#
# The Purpose of this project is to Perform comprehensive analysis on forest fires, analyzing cause, size of fire, seasonal effects, spatial effects and terrain effects.

# %% [markdown]
# ## Data Extraction and Cleaning
#
# This code uses our functions defined in DataExtractionCleaning.py to put our data into a Pandas Dataframe and has functions designed to filter data.

# %%
#necessary imports
from Data_Extracting_and_Cleaning import DataExtractionCleaning as dec
#from Data_Extracting_and_Cleaning.Utils import Directory_utils as Dir
from Analysis_and_Visualization_for_Obtaining_Statistics import AnalysisVisualization as anl

# %%
#load the Dataset
df = dec.Get_all_data("af-historic-wildfires-1996-2005-data.csv")
df.head()
# Out:
#   fire_number fire_name  calendar_year assessment_datetime  \
# 0      E01001       NaN           1996 1996-05-06 19:10:00
# 1      E01002       NaN           1996 1996-05-19 19:37:00
# 2      E01003       NaN           1996 1996-05-24 21:00:00
# 3      E01004       NaN           1996 1996-05-29 17:14:00
# 4      E01005       NaN           1996 1996-05-30 15:35:00
#
#    assessment_hectares  current_size size_class  fire_location_latitude  \
# 0                 1.00           1.0          B                 56.6914
# 1                 0.40           0.4          B                 57.2789
# 2                 1.00           4.0          B                 58.2523
# 3                 0.02           1.2          B                 57.7477
# 4                 0.04           1.6          B                 57.5501
#
#    fire_location_longitude         fire_origin  ...  \
# 0                -111.3831     Provincial Land  ...
# 1                -111.5762     Provincial Land  ...
# 2                -110.5540  Indian Reservation  ...
# 3                -112.6786     Provincial Land  ...
# 4                -111.2103     Provincial Land  ...
#
#                        fuel_type other_fuel_type          bh_fs_date  \
# 0                   matted grass      Known Fuel 1996-05-06 19:20:00
# 1    boreal mixedwood - leafless      Known Fuel 1996-05-19 15:30:00
# 2   Jack or Lodgepole Pine slash         Willows 1996-05-25 09:58:00
# 3                  boreal spruce      Known Fuel 1996-05-29 20:05:00
# 4  mature Jack or Lodgepole Pine      Known Fuel 1996-05-31 01:00:00
#
#   bh_hectares          uc_fs_date uc_hectares          to_fs_date to_hectares  \
# 0         1.0 1996-05-06 19:20:00         1.0                 NaT         NaN
# 1         0.4 1996-05-19 15:30:00         0.4                 NaT         NaN
# 2         4.0 1996-05-25 09:58:00         4.0 1996-05-25 15:59:00         4.0
# 3         1.2 1996-05-30 13:00:00         1.2                 NaT         NaN
# 4         0.8 1996-05-31 01:00:00         0.8                 NaT         NaN
#
#            ex_fs_date ex_hectares
# 0 1996-05-07 11:00:00         1.0
# 1 1996-05-19 18:15:00         0.4
# 2 1996-05-25 16:00:00         4.0
# 3 1996-05-30 20:10:00         1.2
# 4 1996-05-31 20:00:00         1.6
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Analysis and Visualization

# %% [markdown]
# Breakdown of Fires by Year:
# While most years have a considerable number of fires 1998 and 2002 have considerably more hecatares burned than the other years meaning these years fires had a devastating effect.

# %%
anl.plot_graph_of_series(df["calendar_year"].value_counts(sort=False), "bar", "Fires by Year", ["Year", "Number of Fires"])
sum_burn_area_by_year = anl.get_operation_of_series_based_on_another_series(df,["calendar_year","ex_hectares"], op= 'sum')
anl.plot_graph_of_series(sum_burn_area_by_year, "bar", "Sum of the Burn Areas per Year", ["Year", "Total Hectares Burned"])

# %% [markdown]
# Pie Chart of the general Causes of Fires

# %%
anl.plot_graph_of_series(df["general_cause_desc"].value_counts(sort = False), "pie", "")

# %% [markdown]
# When the general cause is not lightning our dataset provides us with a secondary True Cause when reported.

# %%
anl.plot_graph_of_series(df["true_cause"].value_counts(sort= False), "pie", "")

# %% [markdown]
# Breakdown of fires cause by industry

# %%
anl.plot_graph_of_series(df["industry_identifier_desc"].value_counts(sort= False), "pie", "")

# %% [markdown]
# Breakdown of Fires by responsible parties

# %%
distribution_by_parties = anl.get_operation_of_series_based_on_another_series(df,["responsible_group_desc","responsible_group_desc"], op= 'norm', threshold = 0.5)
anl.plot_graph_of_series(distribution_by_parties, "pie", "")
anl.plot_graph_of_series(distribution_by_parties, "barh", "Fires by Responsible Parties", ["Percentages", "Responsible Parties"])

# %% [markdown]
# Breakdown of Fires by activities (when applicable)

# %%
distribution_by_activities = anl.get_operation_of_series_based_on_another_series(df,["activity_class","activity_class"], op= 'norm', threshold=0.5)
anl.plot_graph_of_series(distribution_by_activities, "barh", "Fires by activity", ["Percentages", "Activities"])

# %% [markdown]
# A breakdown of how weather correlates to the average size of burn areas

# %%
average_burn_area_by_weather = anl.get_operation_of_series_based_on_another_series(df,["weather_conditions_over_fire","ex_hectares"], op= 'mean')
anl.plot_graph_of_series( average_burn_area_by_weather, "bar", "Average Burn Areas Based on Weather", ["Weather Condition", "Average Hectares Burned"])

# %% [markdown]
# Breakdown of Fuel Type

# %%
distribution_by_fuel_type = anl.get_operation_of_series_based_on_another_series(df,["fuel_type","fuel_type"], op= 'norm', threshold=0.5)
anl.plot_graph_of_series(distribution_by_fuel_type, "barh", "Fires by Fuel Type", ["Percentages", "Fuel Type"])

# %% [markdown]
# We can then take the average areas based on fuel type to find which fuels result in the biggest fires

# %%
average_burn_area_by_fuel_type = anl.get_operation_of_series_based_on_another_series(df,["fuel_type","ex_hectares"], op= 'mean',threshold=0.5)
anl.plot_graph_of_series( average_burn_area_by_fuel_type, "barh", "Average Burn Areas Based on Fuel Type", [ "Average Hectares Burned","Fuel Type"])

# %% [markdown]
# Breakdown of Fires by Fire Origin and breakdown of Fire Origin and land burned. DND is Canada's Department of National Defense. We can see that DND had very little fires overall but each fire averaged roughly 375 hecatres.

# %%
anl.plot_graph_of_series(df["fire_origin"].value_counts(sort= False), "pie", "")
average_burn_area_by_fire_origin = anl.get_operation_of_series_based_on_another_series(df,["fire_origin","ex_hectares"], op="mean")
anl.plot_graph_of_series( average_burn_area_by_fire_origin, "barh", "Average Burn Areas Based on Fire Origin", ["Average Hectares Burned","Fire Origin"])
sum_burn_area_by_fire_origin = anl.get_operation_of_series_based_on_another_series(df,["fire_origin","ex_hectares"], op="sum")
anl.plot_graph_of_series( sum_burn_area_by_fire_origin, "barh", "Total Burn Areas Based on Fire Origin", [ "Total Hectares Burned","Fire Origin"])

# %% [markdown]
# ## Breakdown of Fires by Fire Type:
# ### Ground Fires:
# Ground fires – also known as ‘subsurface fires’ – can occur in areas with large accumulations of dead vegetation over time, such as humus and peat. They move slowly beneath the surface terrain, making them difficult to see from above. In some cases, ground fires can continue to smolder underground throughout the winter and reignite aboveground again in the spring. This scenario is more likely during a period of prolonged drought.
# Ground Fires are more common than crown fires but way less common than surface fires and tend to burn the least amount of land.
#
# ### Surface Fires:
# Surface fires burn detritus such as litter, twigs, and leaves, which sit on the surface of the ground. They can also consume surface vegetation, such as shrubs and grasses.
# We can learn that most fires are surface fires and tend to burn more than ground fires but considerably less than crown fires.
#
# ### Crown Fires:
# A crown fire burns in the tree canopy and jumps between trees.
# You can see in our bar graph that crown fires typically burn way more land but are the least common.
# Definitions from [Types of Wildfires](https://wfca.com/wildfire-articles/types-of-wildfire/)

# %%
anl.plot_graph_of_series(df["fire_type"].value_counts(sort= False), "pie", "")
average_burn_area_by_fire_type = anl.get_operation_of_series_based_on_another_series(df,["fire_type","ex_hectares"], op= 'mean')
anl.plot_graph_of_series( average_burn_area_by_fire_type, "bar", "Average Burn Areas Based on Fire Type", ["Fire Type", "Average Hectares Burned"])

# %% [markdown]
# ## Predictions

# %% [markdown]
# Apply three machine learning models to predict the size of fire:
# 1. Random Forest
# 2. Support Vector Machine
# 3. Gradient Boosting Regressor

# %% [markdown]
# ### Random Forest

# %%
# Train a random forest regression model
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(X_train, y_train)

# make predictions
y_pred_train = rf_regressor.predict(X_train)
y_pred_test = rf_regressor.predict(X_test)

# %% [markdown]
# ### Supprt Vector Machine

# %%
# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the SVM model
svr_model = SVR()
svr_model.fit(X_train_scaled, y_train)

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
# Train a gradient boosted tree model
gb_regressor = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gb_regressor.fit(X_train, y_train)

# %% [markdown]
# Model Criteria
# 1. Mean Square Error(MSE)
# 2. Coefficient of Determination(R^2)

# %% [markdown]
# ![image.png](attachment:image.png)
